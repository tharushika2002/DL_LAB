# %%
import numpy as np

# %%
import pandas as pd

# %%
nano_data = pd.read_csv('Au_nanoparticle_dataset.csv')

# %%
nano_data.shape
# Out:
# (4000, 185)

# %%
nano_data.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
#    q6q6_S20  q6q6_S20+     Total_E  Formation_E
# 0         0          0  -5908.6345     343.4555
# 1         0          0  -6035.4034     384.8166
# 2         0          0 -17330.1660     800.5040
# 3         0          0 -26937.2010    1171.7890
# 4         0          0 -41427.9010    1597.7390
#
# [5 rows x 185 columns]

# %%
nano_data.tail()
# Out:
#         ID    T      tau  time  N_total  N_bulk  N_surface        Volume  \
# 3995  3996  973  0.00025     6     1509     950        559  2.550000e-26
# 3996  3997  973  0.00025     7     2315    1469        846  3.920000e-26
# 3997  3998  973  0.00025     8     2764    1905        859  4.680000e-26
# 3998  3999  973  0.00025     9     3148    2199        949  5.330000e-26
# 3999  4000  973  0.00025    10     3986    2785       1201  6.750000e-26
#
#         R_min    R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  \
# 3995  13.8048  23.1729  ...         0         0         0         0         0
# 3996  12.0020  36.7573  ...         0         0         0         0         0
# 3997  18.8611  24.6101  ...         0         0         0         0         0
# 3998  18.7624  26.0008  ...         0         0         0         0         0
# 3999  19.1334  44.7678  ...         0         0         0         0         0
#
#       q6q6_S19  q6q6_S20  q6q6_S20+     Total_E  Formation_E
# 3995         0         0          0  -5346.9589     553.2311
# 3996         0         0          0  -8218.1252     833.5248
# 3997         0         0          0  -9876.2899     930.9501
# 3998         0         0          0 -11261.0810    1047.5990
# 3999         0         0          0 -14264.3970          NaN
#
# [5 rows x 185 columns]

# %%
nano_data['R_avg']
# Out:
# 0       17.3706
# 1       17.6061
# 2       25.3692
# 3       29.7011
# 4       34.2831
#          ...
# 3995    17.4079
# 3996    21.2937
# 3997    21.4990
# 3998    22.5111
# 3999    25.5906
# Name: R_avg, Length: 4000, dtype: float64

# %% [markdown]
# ### 1. Create a new dataframe by filtering all the columns [i.e., features] except N_total, N_bulk, N_surface and R_avg columns.

# %%
excepcol = ['N_total', 'N_bulk' , 'N_surface' , 'R_avg']

# %%
new_nano_data = nano_data.drop(columns = excepcol)

# %%
new_nano_data.shape
# Out:
# (4000, 181)

# %% [markdown]
# ### 2. Display the first 20 samples of this dataframe

# %%
new_nano_data.sample(20)
# Out:
#         ID    T       tau  time        Volume    R_min    R_max   R_diff  \
# 1613  1614  523  0.000000    10  3.680000e-26  17.3954  22.6719   5.2765
# 1770         0         0          0 -34644.5530    2039.0670
# 1328         0         0          0  -2783.3614     254.7086
# 2723         0         0          0 -19397.3660    1583.6940
# 815          0         0          0 -46885.4080    1688.5220
# 1887         0         0          0 -14023.7830     920.2370
# 961          0         0          0  -2379.8512     200.7488
# 1999         0         0          0 -16180.9690     976.1110
# 3484         0         0          0  -5041.7419     682.4981
# 1007         0         0          0 -53279.1680    1793.1820
# 2616         0         0          0  -7814.8655     705.0245
# 2946         0         0          0 -21198.8630    1584.7070
#
# [20 rows x 181 columns]

# %% [markdown]
# ### 3. Calculate the mean, standard deviation and quartile values for each of the above 4 features.

# %%
mean = nano_data[excepcol].mean()

# %%
print (f'All means \n {mean}')
# Out:
# All means
#  N_total      3476.786500
# N_bulk       2521.550250
# N_surface     955.236250
# R_avg          20.654363
# dtype: float64

# %%
std = nano_data[excepcol].std()

# %%
print (f'all std \n {std}')
# Out:
# all std
#  N_total      3679.286769
# N_bulk       2976.232459
# N_surface     721.870220
# R_avg           7.610716
# dtype: float64

# %%
allQuartile = nano_data[excepcol].quantile([0.25,0.50,0.75])
print (allQuartile)
# Out:
#       N_total   N_bulk  N_surface      R_avg
# 0.25   1061.0   618.75     437.00  15.160725
# 0.50   1867.0  1199.00     666.00  18.629250
# 0.75   4503.0  3183.00    1301.75  25.525125

# %%
import matplotlib 
import matplotlib.pyplot as plt

# %%
fig , axes = plt.subplots(nrows=1, ncols=4 , figsize=(20,4))

for i in range(4):
    axes[i].hist(nano_data[excepcol[i]], bins=30, color='Blue', edgecolor = 'Yellow')
    axes[i].set_title(f'Histogram {i+1}')
    axes[i].set_xlabel('Values')
    axes[i].set_ylabel('Frequency')

# %%
import seaborn as sn

# %%
new_nano_data.head(5)
# Out:
#    ID    T       tau  time        Volume    R_min    R_max   R_diff   R_std  \
# 0   1  273  0.000025     1  2.710000e-26  15.5898  19.4516   3.8618  0.6230
# 1   2  273  0.000025     2  2.780000e-26  15.3996  24.1755   8.7760  0.9295
# 2   3  273  0.000025     3  7.850000e-26  21.9199  31.0305   9.1106  1.0701
# 3   4  273  0.000025     4  1.220000e-25  23.2542  37.8795  14.6253  2.3732
# 4   5  273  0.000025     5  1.860000e-25  27.1200  39.7614  12.6415  1.9397
#
#    R_skew  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0 -0.0435  ...         0         0         0         0         0         0
# 1  2.0673  ...         0         0         0         0         0         0
# 2  0.3618  ...         0         0         0         0         0         0
# 3  0.1431  ...         0         0         0         0         0         0
# 4 -0.3849  ...         0         0         0         0         0         0
#
#    q6q6_S20  q6q6_S20+     Total_E  Formation_E
# 0         0          0  -5908.6345     343.4555
# 1         0          0  -6035.4034     384.8166
# 2         0          0 -17330.1660     800.5040
# 3         0          0 -26937.2010    1171.7890
# 4         0          0 -41427.9010    1597.7390
#
# [5 rows x 181 columns]

# %%
sn.pairplot( data = nano_data[excepcol])
plt.show()

# %%
g = sn.PairGrid(nano_data[excepcol])
g.map_upper(sn.histplot) #bivariate histogram
g.map_diag(sn.histplot , kde=True ) # kde=True in histplot adds a smooth curve to the histogram.
g.map_lower(sn.kdeplot)
